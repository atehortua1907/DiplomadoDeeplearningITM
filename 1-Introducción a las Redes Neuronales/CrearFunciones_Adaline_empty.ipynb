# %% [markdown]
# ### Adaline
#
# En este notebook se pretende crear todos los pasos para entrenar y validar una red adaline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple/
# Out:
# /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple

# %% [markdown]
# ### Importar Librerias

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd

# %% [markdown]
# ### Leer la base de datos

# %%
file= 'trainAdaline.csv'

data= pd.___(file, header = None) #Load DataBase
X= data.iloc[:,1:].values  # Features
S= data.iloc[:,0].values   # Target

# %% [markdown]
# ### Inicializar Parámetros

# %%
dim= 3

np.random.seed(1)

w =                         # se generan valores aleatorios a los pesos
b = 0                       # se asigna a 0 el valor del bias

print('w', w, 'b', b)
# Out:
# w [[ 1.62434536]
#  [-0.61175641]
#  [-0.52817175]] b 0

# %% [markdown]
# ### Forward:
# Implementa la parte lineal de la propagación hacia adelante]

# %%
x= X[0,:]

Z= ______ + b
print('Z', Z)
# Out:
# Z [0.]

# %% [markdown]
# Calcular la función de activación

# %%
Y= ___
print('Y:', Y)
# Out:
# Y: [0.]

# %% [markdown]
# ### Calcular Función de error

# %%
s=S[1]

error= _______
    
print('s', s, 'error:', error)
# Out:
# s 1 error: [0.5]

# %% [markdown]
# ### Backward: Proceso de aprendizaje

# %%
f=0.1

dw = ________
db = ________

print('dw:', dw, 'db:', db)
# Out:
# dw: [[0.]
#  [0.]
#  [0.]] db: [0.1]

# %% [markdown]
# ### Actualización de Pesos

# %%
w = w + __
b = b + __
print('w:', w, 'b', b)
# Out:
# w: [[ 1.62434536]
#  [-0.61175641]
#  [-0.52817175]] b [0.1]
