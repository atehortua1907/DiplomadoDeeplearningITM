# %% [markdown]
# ### **Aplicación Adaline**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple/
# Out:
# /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple

# %% [markdown]
# Importar las librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd
from AdalineV03_Full import *

# %% [markdown]
# Definir la función completa de entrenamiento

# %%
def adaline_model(X, S, f, num_iterations = 10000, min_error=0, print_cost=False):
        
    w,b=_____
        
    errorTotal=0.0
    
    m=len(X[0:,])
    
    costs=[]
    
    contIter=0
    
    #
    for i in range(0, num_iterations):
        
        contIter+=1
        errorTotal=0.0
        
        for i in range(0,m):
            
            # Calculo del nivel de Activación y de la función de Activación
            
            Y=____
            
            # Calculo de Error
            
            error=______
#            
            errorTotal+=error
#            
#            # Calculo del aprendizaje con factor de aprendizaje 0.01
#            
            dw, db= _______
#                
#            # Actualizar Parámetros
#            
            w, b= _______
#            
            error=0
            
        costs.append(errorTotal)
         
        if (errorTotal<=min_error):
            break
        
    if(print_cost== True):
        plt.plot(costs)
        plt.ylabel('cost')
        plt.xlabel('iterations')
        plt.show()
        
    return w, b, contIter

# %% [markdown]
# LLamar a la función de entrenamiento

# %%
#######################   Entrenar el modelo ##################################

file= 'trainAdaline.csv' 
# file= 'colorFrutos.csv' 

X, S=leer_Datos(file)

w, b, contIter = adaline_model(X, S, f=0.01, num_iterations = 1000, min_error=0.00001, print_cost=True)
      
print("número de Iteraciones",contIter)
print("w:",w)
print("b:",b)

###############################################################################
# Out:
# número de Iteraciones 596
# w: [[3.99830128]
#  [1.9982881 ]
#  [0.99829096]]
# b: [0.0030199]

# %% [markdown]
# Predicción

# %%
my_predicted=prediccion(np.array([1,0,1]),w,b) # 5 

my_value_y= 5

print ("y = " + str(np.squeeze(my_value_y)) + ", your model predicts a \"" + str(int(np.squeeze(np.around(my_predicted, decimals=0)))))
# Out:
# y = 5, your model predicts a "5
