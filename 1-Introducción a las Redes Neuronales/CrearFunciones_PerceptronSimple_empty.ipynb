# %% [markdown]
# ### Perceptron Simple
#
# En este notebook se pretende crear todos los pasos para entrenar y validar un perceptron simple

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple/
# Out:
# /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple

# %% [markdown]
# ### Importar Librerias

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd

# %% [markdown]
# ### Leer la base de datos

# %%
file= 'breastCancer.csv'

data= pd._____(file, header = None) #Load DataBase
X= data.iloc[:,1:].values  # Features
S= _____   # Target

# %% [markdown]
# ### Inicializar Parámetros

# %%
dim= 9

np.random.seed(1)

w = np.random.randn(dim,1)  # se generan valores aleatorios a los pesos
b = 0                       # se asigna a 0 el valor del bias

print('w', w, 'b', b)
# Out:
# w [[ 1.62434536]
#  [-0.61175641]
#  [-0.52817175]
#  [-1.07296862]
#  [ 0.86540763]
#  [-2.3015387 ]
#  [ 1.74481176]
#  [-0.7612069 ]
#  [ 0.3190391 ]] b 0

# %% [markdown]
# ### Forward:
# Implementa la parte lineal de la propagación hacia adelante]

# %%
x= X[0,:]

Z= ______ + b
print('Z', Z)
# Out:
# Z [0.1433691]

# %% [markdown]
# Calcular la función de activación

# %%
if(Z>0):
    ____
else:
    ____
print('Y:', Y)
# Out:
# Y: 1

# %% [markdown]
# ### Calcular Función de error

# %%
s=S[0]

if (Y != s):
    _____
else:
    _____
    
print('s', s, 'error:', error)
# Out:
# s -1 error: 1

# %% [markdown]
# ### Backward: Proceso de aprendizaje

# %%
if(error==1):
    dw = _________
    db = s
else:
    dw=np.zeros((len(x),1))
    db=0

print('dw:', dw, 'db:', db)
# Out:
# dw: [[-1]
#  [-1]
#  [-1]
#  [-1]
#  [-2]
#  [-1]
#  [-1]
#  [-1]
#  [-1]] db: -1

# %% [markdown]
# ### Actualización de Pesos

# %%
w = w + __
b = b + __
print('w:', w, 'b', b)
# Out:
# w: [[ 0.62434536]
#  [-1.61175641]
#  [-1.52817175]
#  [-2.07296862]
#  [-1.13459237]
#  [-3.3015387 ]
#  [ 0.74481176]
#  [-1.7612069 ]
#  [-0.6809609 ]] b -1
