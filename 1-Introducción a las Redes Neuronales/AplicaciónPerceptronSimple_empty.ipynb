# %% [markdown]
# ### **Aplicación de Perceptron Simple**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple/
# Out:
# /content/drive/My Drive/ITM/Extensión/DeepLearning/Cohorte1-2020/Clase#4. PerceptronSimple

# %% [markdown]
# Importar las librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd
from PerceptronSimpleV03_Full import *

# %% [markdown]
# Definir la función completa de entrenamiento

# %%
def simplePerceptron_model(X, S, num_iterations = 1000, min_error=0, print_cost=False):
        
    w,b= _____
        
    errorTotal=0.0
    m=len(X[0:,])
    
    costs=[]
    
    contIter=0
    
    #
    for i in range(0, num_iterations):
        
        contIter+=1
        errorTotal=0.0
        
        for i in range(0,m):
            
            # Calculo del nivel de Activación y de la función de Activación
            
            Y= ______
            
            # Calculo de Error
            
            error= ______
#            
            errorTotal+=error
#            
#            # Calculo del aprendizaje
#            
            dw, db= ______
#                
#            # Actualizar Parámetros
#            
            w, b= ______
#            
            error=0
            
        costs.append(errorTotal/m)
         
        if (errorTotal/m<=min_error):
            break
    
    if(print_cost== True):
        plt.plot(costs)
        plt.ylabel('cost')
        plt.xlabel('iterations')
        plt.show()
        
    return w, b, costs, contIter

# %% [markdown]
# LLamar a la función de entrenamiento

# %%
#######################   Entrenar el modelo ##################################

# file='trainAND.csv'
file= 'breastCancer.csv'

X, S=leer_Datos(file)

w, b, costs, contIter = simplePerceptron_model(X, S, num_iterations = 10000, min_error=0.02, print_cost=True)

print("número de Iteraciones",contIter)
print("w:",w)
print("b:",b)

###############################################################################
# Out:
# número de Iteraciones 24
# w: [[ 9.62434536]
#  [21.38824359]
#  [ 8.47182825]
#  [ 3.92703138]
#  [-2.13459237]
#  [18.6984613 ]
#  [11.74481176]
#  [10.2387931 ]
#  [ 6.3190391 ]]
# b: [-157]

# %% [markdown]
# Predicción

# %%
# my_predicted=prediccion(np.array([1,-1]),w,b) # AND
my_predicted=prediccion(np.array([8, 8, 7, 4, 10, 10, 7, 8, 7]), w, b) # Cancer

my_label_y= 1

print ("y = " + str(np.squeeze(my_label_y)) + ", your model predicts a \"" + str(int(np.squeeze(my_predicted))))
# Out:
# y = 1, your model predicts a "1
